# %%
# SETTING THE BOARD: ASSIGNING SQUARES AS CHUTES OR LADDERS
CHUTES_LADDERS = {2: 28, 7: 19, 9: 31, 17: 4, 21: 42, 28: 84, 36: 44,
                  47: 26, 49: 11, 51: 67, 56: 53, 62: 19, 64: 60,
                  69: 81, 80: 100, 87: 24, 93: 73, 95: 75, 98: 78}

# %%
# SHOW ONLY GAME WINNERS


def simulate_game_winners_only(rseed=None, max_roll=6):

    rand = Random(rseed)
    p2position = 0
    p1position = 0
    turns = 0
    winner = 0

    while p1position < 100 and p2position < 100:
                
        turns += 1

        # PLAYER 1 ====================================================

        roll = rand.randint(1, max_roll)
        
        if p1position + roll > 100:
            continue
            
        p1position += roll
        
        p1position = CHUTES_LADDERS.get(p1position, p1position)
        
        # PLAYER 2 =====================================================

        if p1position < 100:
            roll = rand.randint(1, max_roll)
        
            if p2position + roll > 100:
                continue

            p2position += roll 

            p2position = CHUTES_LADDERS.get(p2position, p2position)

            if p2position == 100:
                winner = 2
                break    

        else:
            winner = 1
            break

    return turns, winner

# SHOW TURN BY TURN BREAKDOWN


def simulate_full_game(rseed=None, max_roll=6):

    rand = Random(rseed)
    p2position = 0
    p1position = 0
    winner = 0
    turns = 0
    while p1position < 100 and p2position < 100:
                
        turns += 1

        # PLAYER 1 =============================================================

        roll = rand.randint(1, max_roll)
        
        if p1position + roll > 100:
            continue
            
        p1position += roll
        p1landing = p1position

        print("Player 1 rolls " + str(roll) + " and lands at " + str(p1position))
        
        p1position = CHUTES_LADDERS.get(p1position, p1position)
        if p1landing < p1position:
            print("Player 1 is on a ladder tile and moves up to " + str(p1position))
        elif p1landing > p1position:
            print("Player 1 is on a chute tile and moves down to " + str(p1position))

        print("NEXT TURN =====================\n")
        
        # PLAYER 2 =============================================================

        if p1position < 100: 
            roll = rand.randint(1, max_roll)
        
            if p2position + roll > 100:
                continue
              
            p2position += roll  
            p2landing = p2position

            print("Player 2 rolls " + str(roll) + " and lands at " + str(p2position))

            p2position = CHUTES_LADDERS.get(p2position, p2position)
            if p2landing < p2position:
                print("Player 2 is on a ladder tile and moves up to " + str(p2position))
            elif p2landing > p2position:
                print("Player 2 is on a chute tile and moves down to " + str(p2position))
            
            print("NEXT TURN =====================\n")

            if p2position == 100:
                winner = 2
                break        

        else:
            winner = 1
            break

    print("\nGAME END ====================================================== WINNER is Player " + str(winner) + " at " + str(turns) + " turns \n")
    return turns, winner

# %%
# VIEW SETTINGS ==============================


full_game = True  # Set to True if you want to see each game turn by turn.


see_game_winner = True  # Set this to True and 'full_game' to False if you only want to see the Winner for each game.


x = 0  # 100 - X = How many games you want to Simulate

# ============================================

p1wins = 0
p2wins = 0

while x < 100:

    if full_game is True:

        simulate_game_winners_only()

        if simulate_full_game()[1] == 1:
            p1wins += 1  
        else:
            p2wins += 1  

    else: 
        simulate_game_winners_only()
        if simulate_game_winners_only()[1] == 1:
            p1wins += 1  
            if see_game_winner is True:
                print("Player 1 wins at " + str(simulate_game_winners_only()[0]) + " turns")
        else:
            p2wins += 1  
            if see_game_winner is True:
                print("Player 2 wins at " + str(simulate_game_winners_only()[0]) + " turns")

    x += 1  

print("\nTotal Player 1 Wins: " + str(p1wins) + " - " + "Total Player 2 Wins: " + str(p2wins))
# Out:
# Player 1 rolls 3 and lands at
is on a ladder tile and moves up to 100
# NEXT TURN =====================
#
#
# GAME END ====================================================== WINNER is Player 2 at 22 turns
#
# Player 1 rolls 3 and lands at 3
# NEXT TURN =====================
#
# Player 2 rolls 6 and lands at 6
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 7
# Player 1 is on a ladder tile and moves up to 19
# NEXT TURN =====================
#
# Player 2 rolls 6 and lands at 12
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 24
# NEXT TURN =====================
#
# Player 2 rolls 6 and lands at 18
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 29
# NEXT TURN =====================
#
# Player 2 rolls 3 and lands at 21
# Player 2 is on a ladder tile and moves up to 42
# NEXT TURN =====================
#
# Player 1 rolls 1 and lands at 30
# NEXT TURN =====================
#
# Player 2 rolls 1 and lands at 43
# NEXT TURN =====================
#
# Player 1 rolls 6 and lands at 36
# Player 1 is on a ladder tile and moves up to 44
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 45
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 48
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 47
# Player 2 is on a chute tile and moves down to 26
# NEXT TURN =====================
#
# Player 1 rolls 2 and lands at 50
# NEXT TURN =====================
#
# Player 2 rolls 1 and lands at 27
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 54
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 29
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 58
# NEXT TURN =====================
#
# Player 2 rolls 4 and lands at 33
# NEXT TURN =====================
#
# Player 1 rolls 6 and lands at 64
# Player 1 is on a chute tile and moves down to 60
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 35
# NEXT TURN =====================
#
# Player 1 rolls 3 and lands at 63
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 37
# NEXT TURN =====================
#
# Player 1 rolls 3 and lands at 66
# NEXT TURN =====================
#
# Player 2 rolls 4 and lands at 41
# NEXT TURN =====================
#
# Player 1 rolls 6 and lands at 72
# NEXT TURN =====================
#
# Player 2 rolls 1 and lands at 42
# NEXT TURN =====================
#
# Player 1 rolls 2 and lands at 74
# NEXT TURN =====================
#
# Player 2 rolls 4 and lands at 46
# NEXT TURN =====================
#
# Player 1 rolls 2 and lands at 76
# NEXT TURN =====================
#
# Player 2 rolls 6 and lands at 52
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 81
# NEXT TURN =====================
#
# Player 2 rolls 4 and lands at 56
# Player 2 is on a chute tile and moves down to 53
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 85
# NEXT TURN =====================
#
# Player 2 rolls 4 and lands at 57
# NEXT TURN =====================
#
# Player 1 rolls 3 and lands at 88
# NEXT TURN =====================
#
# Player 2 rolls 1 and lands at 58
# NEXT TURN =====================
#
# Player 1 rolls 1 and lands at 89
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 60
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 93
# Player 1 is on a chute tile and moves down to 73
# NEXT TURN =====================
#
# Player 2 rolls 6 and lands at 66
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 78
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 68
# NEXT TURN =====================
#
# Player 1 rolls 6 and lands at 84
# NEXT TURN =====================
#
# Player 2 rolls 4 and lands at 72
# NEXT TURN =====================
#
# Player 1 rolls 2 and lands at 86
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 74
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 90
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 76
# NEXT TURN =====================
#
# Player 1 rolls 3 and lands at 93
# Player 1 is on a chute tile and moves down to 73
# NEXT TURN =====================
#
# Player 2 rolls 4 and lands at 80
# Player 2 is on a ladder tile and moves up to 100
# NEXT TURN =====================
#
#
# GAME END ====================================================== WINNER is Player 2 at 26 turns
#
# Player 1 rolls 2 and lands at 2
# Player 1 is on a ladder tile and moves up to 28
# NEXT TURN =====================
#
# Player 2 rolls 5 and lands at 5
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 32
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 7
# Player 2 is on a ladder tile and moves up to 19
# NEXT TURN =====================
#
# Player 1 rolls 2 and lands at 34
# NEXT TURN =====================
#
# Player 2 rolls 3 and lands at 22
# NEXT TURN =====================
#
# Player 1 rolls 1 and lands at 35
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 24
# NEXT TURN =====================
#
# Player 1 rolls 6 and lands at 41
# NEXT TURN =====================
#
# Player 2 rolls 1 and lands at 25
# NEXT TURN =====================
#
# Player 1 rolls 2 and lands at 43
# NEXT TURN =====================
#
# Player 2 rolls 5 and lands at 30
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 47
# Player 1 is on a chute tile and moves down to 26
# NEXT TURN =====================
#
# Player 2 rolls 5 and lands at 35
# NEXT TURN =====================
#
# Player 1 rolls 6 and lands at 32
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 37
# NEXT TURN =====================
#
# Player 1 rolls 3 and lands at 35
# NEXT TURN =====================
#
# Player 2 rolls 3 and lands at 40
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 40
# NEXT TURN =====================
#
# Player 2 rolls 3 and lands at 43
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 45
# NEXT TURN =====================
#
# Player 2 rolls 3 and lands at 46
# NEXT TURN =====================
#
# Player 1 rolls 3 and lands at 48
# NEXT TURN =====================
#
# Player 2 rolls 1 and lands at 47
# Player 2 is on a chute tile and moves down to 26
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 53
# NEXT TURN =====================
#
# Player 2 rolls 4 and lands at 30
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 57
# NEXT TURN =====================
#
# Player 2 rolls 3 and lands at 33
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 62
# Player 1 is on a chute tile and moves down to 19
# NEXT TURN =====================
#
# Player 2 rolls 3 and lands at 36
# Player 2 is on a ladder tile and moves up to 44
# NEXT TURN =====================
#
# Player 1 rolls 2 and lands at 21
# Player 1 is on a ladder tile and moves up to 42
# NEXT TURN =====================
#
# Player 2 rolls 5 and lands at 49
# Player 2 is on a chute tile and moves down to 11
# NEXT TURN =====================
#
# Player 1 rolls 2 and lands at 44
# NEXT TURN =====================
#
# Player 2 rolls 5 and lands at 16
# NEXT TURN =====================
#
# Player 1 rolls 1 and lands at 45
# NEXT TURN =====================
#
# Player 2 rolls 5 and lands at 21
# Player 2 is on a ladder tile and moves up to 42
# NEXT TURN =====================
#
# Player 1 rolls 2 and lands at 47
# Player 1 is on a chute tile and moves down to 26
# NEXT TURN =====================
#
# Player 2 rolls 4 and lands at 46
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 30
# NEXT TURN =====================
#
# Player 2 rolls 6 and lands at 52
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 34
# NEXT TURN =====================
#
# Player 2 rolls 4 and lands at 56
# Player 2 is on a chute tile and moves down to 53
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 38
# NEXT TURN =====================
#
# Player 2 rolls 5 and lands at 58
# NEXT TURN =====================
#
# Player 1 rolls 3 and lands at 41
# NEXT TURN =====================
#
# Player 2 rolls 1 and lands at 59
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 45
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 61
# NEXT TURN =====================
#
# Player 1 rolls 1 and lands at 46
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 63
# NEXT TURN =====================
#
# Player 1 rolls 1 and lands at 47
# Player 1 is on a chute tile and moves down to 26
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 65
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 31
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 67
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 35
# NEXT TURN =====================
#
# Player 2 rolls 6 and lands at 73
# NEXT TURN =====================
#
# Player 1 rolls 2 and lands at 37
# NEXT TURN =====================
#
# Player 2 rolls 6 and lands at 79
# NEXT TURN =====================
#
# Player 1 rolls 1 and lands at 38
# NEXT TURN =====================
#
# Player 2 rolls 5 and lands at 84
# NEXT TURN =====================
#
# Player 1 rolls 6 and lands at 44
# NEXT TURN =====================
#
# Player 2 rolls 4 and lands at 88
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 49
# Player 1 is on a chute tile and moves down to 11
# NEXT TURN =====================
#
# Player 2 rolls 3 and lands at 91
# NEXT TURN =====================
#
# Player 1 rolls 2 and lands at 13
# NEXT TURN =====================
#
# Player 2 rolls 5 and lands at 96
# NEXT TURN =====================
#
# Player 1 rolls 1 and lands at 14
# NEXT TURN =====================
#
# Player 1 rolls 2 and lands at 16
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 98
# Player 2 is on a chute tile and moves down to 78
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 21
# Player 1 is on a ladder tile and moves up to 42
# NEXT TURN =====================
#
# Player 2 rolls 5 and lands at 83
# NEXT TURN =====================
#
# Player 1 rolls 1 and lands at 43
# NEXT TURN =====================
#
# ...
#
# Player 1 rolls 2 and lands at 50
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 55
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 60
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 64
# Player 1 is on a chute tile and moves down to 60
# NEXT TURN =====================
#
# Player 1 rolls 2 and lands at 62
# Player 1 is on a chute tile and moves down to 19
# NEXT TURN =====================
#
# Player 1 rolls 1 and lands at 20
# NEXT TURN =====================
#
# Player 2 rolls 1 and lands at 100
# NEXT TURN =====================
#
#
# GAME END ====================================================== WINNER is Player 2 at 64 turns
#
# Player 1 rolls 1 and lands at 1
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 2
# Player 2 is on a ladder tile and moves up to 28
# NEXT TURN =====================
#
# Player 1 rolls 6 and lands at 7
# Player 1 is on a ladder tile and moves up to 19
# NEXT TURN =====================
#
# Player 2 rolls 4 and lands at 32
# NEXT TURN =====================
#
# Player 1 rolls 2 and lands at 21
# Player 1 is on a ladder tile and moves up to 42
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 34
# NEXT TURN =====================
#
# Player 1 rolls 2 and lands at 44
# NEXT TURN =====================
#
# Player 2 rolls 6 and lands at 40
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 49
# Player 1 is on a chute tile and moves down to 11
# NEXT TURN =====================
#
# Player 2 rolls 6 and lands at 46
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 15
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 48
# NEXT TURN =====================
#
# Player 1 rolls 3 and lands at 18
# NEXT TURN =====================
#
# Player 2 rolls 5 and lands at 53
# NEXT TURN =====================
#
# Player 1 rolls 2 and lands at 20
# NEXT TURN =====================
#
# Player 2 rolls 5 and lands at 58
# NEXT TURN =====================
#
# Player 1 rolls 1 and lands at 21
# Player 1 is on a ladder tile and moves up to 42
# NEXT TURN =====================
#
# Player 2 rolls 6 and lands at 64
# Player 2 is on a chute tile and moves down to 60
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 47
# Player 1 is on a chute tile and moves down to 26
# NEXT TURN =====================
#
# Player 2 rolls 4 and lands at 64
# Player 2 is on a chute tile and moves down to 60
# NEXT TURN =====================
#
# Player 1 rolls 1 and lands at 27
# NEXT TURN =====================
#
# Player 2 rolls 4 and lands at 64
# Player 2 is on a chute tile and moves down to 60
# NEXT TURN =====================
#
# Player 1 rolls 2 and lands at 29
# NEXT TURN =====================
#
# Player 2 rolls 6 and lands at 66
# NEXT TURN =====================
#
# Player 1 rolls 6 and lands at 35
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 68
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 39
# NEXT TURN =====================
#
# Player 2 rolls 1 and lands at 69
# Player 2 is on a ladder tile and moves up to 81
# NEXT TURN =====================
#
# Player 1 rolls 1 and lands at 40
# NEXT TURN =====================
#
# Player 2 rolls 6 and lands at 87
# Player 2 is on a chute tile and moves down to 24
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 45
# NEXT TURN =====================
#
# Player 2 rolls 5 and lands at 29
# NEXT TURN =====================
#
# Player 1 rolls 1 and lands at 46
# NEXT TURN =====================
#
# Player 2 rolls 5 and lands at 34
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 50
# NEXT TURN =====================
#
# Player 2 rolls 5 and lands at 39
# NEXT TURN =====================
#
# Player 1 rolls 2 and lands at 52
# NEXT TURN =====================
#
# Player 2 rolls 6 and lands at 45
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 57
# NEXT TURN =====================
#
# Player 2 rolls 5 and lands at 50
# NEXT TURN =====================
#
# Player 1 rolls 3 and lands at 60
# NEXT TURN =====================
#
# Player 2 rolls 1 and lands at 51
# Player 2 is on a ladder tile and moves up to 67
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 65
# NEXT TURN =====================
#
# Player 2 rolls 6 and lands at 73
# NEXT TURN =====================
#
# Player 1 rolls 3 and lands at 68
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 75
# NEXT TURN =====================
#
# Player 1 rolls 2 and lands at 70
# NEXT TURN =====================
#
# Player 2 rolls 3 and lands at 78
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 74
# NEXT TURN =====================
#
# Player 2 rolls 1 and lands at 79
# NEXT TURN =====================
#
# Player 1 rolls 3 and lands at 77
# NEXT TURN =====================
#
# Player 2 rolls 1 and lands at 80
# Player 2 is on a ladder tile and moves up to 100
# NEXT TURN =====================
#
#
# GAME END ====================================================== WINNER is Player 2 at 26 turns
#
# Player 1 rolls 1 and lands at 1
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 2
# Player 2 is on a ladder tile and moves up to 28
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 5
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 30
# NEXT TURN =====================
#
# Player 1 rolls 6 and lands at 11
# NEXT TURN =====================
#
# Player 2 rolls 3 and lands at 33
# NEXT TURN =====================
#
# Player 1 rolls 2 and lands at 13
# NEXT TURN =====================
#
# Player 2 rolls 4 and lands at 37
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 18
# NEXT TURN =====================
#
# Player 2 rolls 5 and lands at 42
# NEXT TURN =====================
#
# Player 1 rolls 6 and lands at 24
# NEXT TURN =====================
#
# Player 2 rolls 1 and lands at 43
# NEXT TURN =====================
#
# Player 1 rolls 2 and lands at 26
# NEXT TURN =====================
#
# Player 2 rolls 1 and lands at 44
# NEXT TURN =====================
#
# Player 1 rolls 3 and lands at 29
# NEXT TURN =====================
#
# Player 2 rolls 5 and lands at 49
# Player 2 is on a chute tile and moves down to 11
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 33
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 13
# NEXT TURN =====================
#
# Player 1 rolls 3 and lands at 36
# Player 1 is on a ladder tile and moves up to 44
# NEXT TURN =====================
#
# Player 2 rolls 3 and lands at 16
# NEXT TURN =====================
#
# Player 1 rolls 2 and lands at 46
# NEXT TURN =====================
#
# Player 2 rolls 3 and lands at 19
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 51
# Player 1 is on a ladder tile and moves up to 67
# NEXT TURN =====================
#
# Player 2 rolls 4 and lands at 23
# NEXT TURN =====================
#
# Player 1 rolls 3 and lands at 70
# NEXT TURN =====================
#
# Player 2 rolls 3 and lands at 26
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 74
# NEXT TURN =====================
#
# Player 2 rolls 3 and lands at 29
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 78
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 31
# NEXT TURN =====================
#
# Player 1 rolls 1 and lands at 79
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 33
# NEXT TURN =====================
#
# Player 1 rolls 3 and lands at 82
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 35
# NEXT TURN =====================
#
# Player 1 rolls 3 and lands at 85
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 37
# NEXT TURN =====================
#
# Player 1 rolls 3 and lands at 88
# NEXT TURN =====================
#
# Player 2 rolls 6 and lands at 43
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 92
# NEXT TURN =====================
#
# Player 2 rolls 1 and lands at 44
# NEXT TURN =====================
#
# Player 1 rolls 1 and lands at 93
# Player 1 is on a chute tile and moves down to 73
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 46
# NEXT TURN =====================
#
# Player 1 rolls 3 and lands at 76
# NEXT TURN =====================
#
# Player 2 rolls 4 and lands at 50
# NEXT TURN =====================
#
# Player 1 rolls 2 and lands at 78
# NEXT TURN =====================
#
# Player 2 rolls 5 and lands at 55
# NEXT TURN =====================
#
# Player 1 rolls 2 and lands at 80
# Player 1 is on a ladder tile and moves up to 100
# NEXT TURN =====================
#
#
# GAME END ====================================================== WINNER is Player 1 at 24 turns
#
# Player 1 rolls 1 and lands at 1
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 2
# Player 2 is on a ladder tile and moves up to 28
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 5
# NEXT TURN =====================
#
# Player 2 rolls 3 and lands at 31
# NEXT TURN =====================
#
# Player 1 rolls 3 and lands at 8
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 33
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 13
# NEXT TURN =====================
#
# Player 2 rolls 3 and lands at 36
# Player 2 is on a ladder tile and moves up to 44
# NEXT TURN =====================
#
# Player 1 rolls 1 and lands at 14
# NEXT TURN =====================
#
# Player 2 rolls 4 and lands at 48
# NEXT TURN =====================
#
# Player 1 rolls 6 and lands at 20
# NEXT TURN =====================
#
# Player 2 rolls 6 and lands at 54
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 25
# NEXT TURN =====================
#
# Player 2 rolls 5 and lands at 59
# NEXT TURN =====================
#
# Player 1 rolls 6 and lands at 31
# NEXT TURN =====================
#
# Player 2 rolls 5 and lands at 64
# Player 2 is on a chute tile and moves down to 60
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 35
# NEXT TURN =====================
#
# Player 2 rolls 6 and lands at 66
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 40
# NEXT TURN =====================
#
# Player 2 rolls 3 and lands at 69
# Player 2 is on a ladder tile and moves up to 81
# NEXT TURN =====================
#
# Player 1 rolls 1 and lands at 41
# NEXT TURN =====================
#
# Player 2 rolls 4 and lands at 85
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 45
# NEXT TURN =====================
#
# Player 2 rolls 5 and lands at 90
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 49
# Player 1 is on a chute tile and moves down to 11
# NEXT TURN =====================
#
# Player 2 rolls 6 and lands at 96
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 15
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 19
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 98
# Player 2 is on a chute tile and moves down to 78
# NEXT TURN =====================
#
# Player 1 rolls 1 and lands at 20
# NEXT TURN =====================
#
# Player 2 rolls 6 and lands at 84
# NEXT TURN =====================
#
# Player 1 rolls 6 and lands at 26
# NEXT TURN =====================
#
# Player 2 rolls 3 and lands at 87
# Player 2 is on a chute tile and moves down to 24
# NEXT TURN =====================
#
# Player 1 rolls 1 and lands at 27
# NEXT TURN =====================
#
# Player 2 rolls 3 and lands at 27
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 31
# NEXT TURN =====================
#
# Player 2 rolls 5 and lands at 32
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 36
# Player 1 is on a ladder tile and moves up to 44
# NEXT TURN =====================
#
# Player 2 rolls 5 and lands at 37
# NEXT TURN =====================
#
# Player 1 rolls 1 and lands at 45
# NEXT TURN =====================
#
# Player 2 rolls 3 and lands at 40
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 49
# Player 1 is on a chute tile and moves down to 11
# NEXT TURN =====================
#
# Player 2 rolls 5 and lands at 45
# NEXT TURN =====================
#
# Player 1 rolls 1 and lands at 12
# NEXT TURN =====================
#
# Player 2 rolls 1 and lands at 46
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 17
# Player 1 is on a chute tile and moves down to 4
# NEXT TURN =====================
#
# Player 2 rolls 5 and lands at 51
# Player 2 is on a ladder tile and moves up to 67
# NEXT TURN =====================
#
# Player 1 rolls 2 and lands at 6
# NEXT TURN =====================
#
# Player 2 rolls 3 and lands at 70
# NEXT TURN =====================
#
# Player 1 rolls 3 and lands at 9
# Player 1 is on a ladder tile and moves up to 31
# NEXT TURN =====================
#
# Player 2 rolls 4 and lands at 74
# NEXT TURN =====================
#
# Player 1 rolls 2 and lands at 33
# NEXT TURN =====================
#
# Player 2 rolls 6 and lands at 80
# Player 2 is on a ladder tile and moves up to 100
# NEXT TURN =====================
#
#
# GAME END ====================================================== WINNER is Player 2 at 27 turns
#
# Player 1 rolls 6 and lands at 6
# NEXT TURN =====================
#
# Player 2 rolls 1 and lands at 1
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 10
# NEXT TURN =====================
#
# Player 2 rolls 3 and lands at 4
# NEXT TURN =====================
#
# Player 1 rolls 3 and lands at 13
# NEXT TURN =====================
#
# Player 2 rolls 5 and lands at 9
# Player 2 is on a ladder tile and moves up to 31
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 17
# Player 1 is on a chute tile and moves down to 4
# NEXT TURN =====================
#
# Player 2 rolls 3 and lands at 34
# NEXT TURN =====================
#
# Player 1 rolls 1 and lands at 5
# NEXT TURN =====================
#
# Player 2 rolls 6 and lands at 40
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 10
# NEXT TURN =====================
#
# Player 2 rolls 3 and lands at 43
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 14
# NEXT TURN =====================
#
# Player 2 rolls 1 and lands at 44
# NEXT TURN =====================
#
# Player 1 rolls 1 and lands at 15
# NEXT TURN =====================
#
# Player 2 rolls 3 and lands at 47
# Player 2 is on a chute tile and moves down to 26
# NEXT TURN =====================
#
# Player 1 rolls 3 and lands at 18
# NEXT TURN =====================
#
# Player 2 rolls 6 and lands at 32
# NEXT TURN =====================
#
# Player 1 rolls 1 and lands at 19
# NEXT TURN =====================
#
# Player 2 rolls 3 and lands at 35
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 24
# NEXT TURN =====================
#
# Player 2 rolls 6 and lands at 41
# NEXT TURN =====================
#
# Player 1 rolls 1 and lands at 25
# NEXT TURN =====================
#
# Player 2 rolls 6 and lands at 47
# Player 2 is on a chute tile and moves down to 26
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 29
# NEXT TURN =====================
#
# Player 2 rolls 3 and lands at 29
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 34
# NEXT TURN =====================
#
# Player 2 rolls 3 and lands at 32
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 38
# NEXT TURN =====================
#
# Player 2 rolls 3 and lands at 35
# NEXT TURN =====================
#
# Player 1 rolls 2 and lands at 40
# NEXT TURN =====================
#
# Player 2 rolls 5 and lands at 40
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 45
# NEXT TURN =====================
#
# Player 2 rolls 6 and lands at 46
# NEXT TURN =====================
#
# Player 1 rolls 5 and lands at 50
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 48
# NEXT TURN =====================
#
# Player 1 rolls 1 and lands at 51
# Player 1 is on a ladder tile and moves up to 67
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 50
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 71
# NEXT TURN =====================
#
# Player 2 rolls 2 and lands at 52
# NEXT TURN =====================
#
# Player 1 rolls 4 and lands at 75
# NEXT TURN =====================
#
# Player 2 rolls 6 and lands at 58
# NEXT TURN =====================
#
# Player 1 rolls 2 and lands at 77
# NEXT TURN =====================
#
# Player 2 rolls 4 and lands at 62
# Player 2 is on a chute tile and moves down to 19
# NEXT TURN =====================
#
# Player 1 rolls 3 and lands at 80
# Player 1 is on a ladder tile and moves up to 100
# NEXT TURN =====================
#
#
# GAME END ====================================================== WINNER is Player 1 at 23 turns
#
#
# Total Player 1 Wins: 51 - Total Player 2 Wins: 49
