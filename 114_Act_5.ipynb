# %% [markdown]
# # CHUTES AND LADDERS SETTINGS

# %%
# SETTING THE BOARD: ASSIGNING SQUARES AS CHUTES OR LADDERS
CHUTES_LADDERS = {2: 28, 7: 19, 9: 31, 17: 4, 21: 42, 28: 84, 36: 44,
                  47: 26, 49: 11, 51: 67, 56: 53, 62: 19, 64: 60,
                  69: 81, 80: 99, 87: 24, 93: 73, 95: 75, 98: 78}

# %% [markdown]
# # FUNCTIONS

# %%
from random import Random

# SETTING THE BOARD: ASSIGNING SQUARES AS CHUTES OR LADDERS
CHUTES_LADDERS = {2: 28, 7: 19, 9: 31, 17: 4, 21: 42, 28: 84, 36: 44,
                  47: 26, 49: 11, 51: 67, 56: 53, 62: 19, 64: 60,
                  69: 81, 80: 99, 87: 24, 93: 73, 95: 75, 98: 78}

# SHOW ONLY GAME WINNERS


def simulate_game_winners_only(rseed=None, max_roll=6):

    rand = Random(rseed)
    p2position = 0
    p1position = 0
    turns = 0
    winner = 0

    while p1position < 100 and p2position < 100:
                
        rand = Random(rseed)
        p2position = 0
        p1position = 0
        winner = 0
        turns = 0
        while p1position < 100 and p2position < 100:
                    
            turns += 1

            # PLAYER 1 =============================================================

            roll = rand.randint(1, max_roll)
            
            if p1position + roll > 100:
                p1position += 0
            else:
                p1position += roll
                
                p1position = CHUTES_LADDERS.get(p1position, p1position)
            
            # PLAYER 2 =============================================================

            if p1position < 100: 
                roll = rand.randint(1, max_roll)
            
                if p2position + roll > 100:
                    p2position += 0
                else:                
                    p2position += roll  

                    p2position = CHUTES_LADDERS.get(p2position, p2position)
                
                if p2position == 100:
                    winner = 2
                    break        

            else:
                winner = 1
                break

        return turns, winner  

# SHOW TURN BY TURN BREAKDOWN


def simulate_full_game(rseed=None, max_roll=6):

    rand = Random(rseed)
    p2position = 0
    p1position = 0
    p1startpoint = 0
    p2startpoint = 0
    winner = 0
    turns = 0
    while p1position < 100 and p2position < 100:
                
        turns += 1
        print(str(turns) + " =============================================================")

        # PLAYER 1 =============================================================

        roll = rand.randint(1, max_roll)
        
        if p1position + roll > 100:
            print("Player 1 overshoots square 100 and skips their turn")
        else:
            p1startpoint = p1position     
            p1position += roll
            p1landing = p1position

            print("Player 1 rolls " + str(roll) + " and moves from " + str(p1startpoint) + " and lands at " + str(p1position))
            
            p1position = CHUTES_LADDERS.get(p1position, p1position)
            if p1landing < p1position:
                print("Player 1 is on a ladder tile and moves up to " + str(p1position))
            elif p1landing > p1position:
                print("Player 1 is on a chute tile and moves down to " + str(p1position))

        print("NEXT TURN =====================\n")
        
        # PLAYER 2 =============================================================

        if p1position < 100: 
            roll = rand.randint(1, max_roll)
        
            if p2position + roll > 100:
                print("Player 2 overshoots square 100 and skips their turn")
            else:              
                p2startpoint = p2position   
                p2position += roll  
                p2landing = p2position

                print("Player 2 rolls " + str(roll) + " and moves from " + str(p2startpoint) + " and lands at " + str(p2position))

                p2position = CHUTES_LADDERS.get(p2position, p2position)
                if p2landing < p2position:
                    print("Player 2 is on a ladder tile and moves up to " + str(p2position))
                elif p2landing > p2position:
                    print("Player 2 is on a chute tile and moves down to " + str(p2position))
            
            print("NEXT TURN =====================\n")

            if p2position == 100:
                winner = 2
                break        

        else:
            winner = 1
            break

    print("\nGAME END === WINNER is Player " + str(winner) + " at " + str(turns) + " turns \n")
    return turns, winner

# %% [markdown]
# # RUNNING THE SIMULATION

# %%
# VIEW SETTINGS ==============================

full_game = True  # Set to True if you want to see each game turn by turn.
see_game_winner = True  # Set this to True and 'full_game' to False if you only want to see the Winner for each game.
x = 0  
y = 1  # y - X = How many games you want to Simulate

# ============================================

p1wins = 0
p2wins = 0

p1turn_num = 0
p2turn_num = 0


while x < y:

    if full_game is True:

        simulate_game_winners_only()

        if simulate_full_game()[1] == 1:
            p1wins += 1  
            p1turn_num += simulate_full_game()[0]
        else:
            p2wins += 1  
            p2turn_num += simulate_full_game()[0]

    else: 
        simulate_game_winners_only()
        if simulate_game_winners_only()[1] == 1:
            p1wins += 1  
            p1turn_num += simulate_game_winners_only()[0]
            if see_game_winner is True:
                print("Player 1 wins at " + str(simulate_game_winners_only()[0]) + " turns")
        else:
            p2wins += 1  
            p2turn_num += simulate_game_winners_only()[0]
            if see_game_winner is True:
                
                print("Player 2 wins at " + str(simulate_game_winners_only()[0]) + " turns")

    x += 1  

if y == 1:
    print("")
else:
    print("\n| " + str(x) + " Games Played | Results:")
    print("Total Player 1 Wins: " + str(p1wins) + " at an average " + str(int(p1turn_num/p1wins)) + " turns per win")
    print("Total Player 2 Wins: " + str(p2wins) + " at an average " + str(int(p2turn_num/p1wins)) + " turns per win")
# Out:
# 1 =============================================================
# Player 1 rolls 1 and moves from 0 and lands at 1
# NEXT TURN =====================
#
# Player 2 rolls 4 and moves from 0 and lands at 4
# NEXT TURN =====================
#
# 2 =============================================================
# Player 1 rolls 2 and moves from 1 and lands at 3
# NEXT TURN =====================
#
# Player 2 rolls 3 and moves from 4 and lands at 7
# Player 2 is on a ladder tile and moves up to 19
# NEXT TURN =====================
#
# 3 =============================================================
# Player 1 rolls 3 and moves from 3 and lands at 6
# NEXT TURN =====================
#
# Player 2 rolls 6 and moves from 19 and lands at 25
# NEXT TURN =====================
#
# 4 =============================================================
# Player 1 rolls 3 and moves from 6 and lands at 9
# Player 1 is on a ladder tile and moves up to 31
# NEXT TURN =====================
#
# Player 2 rolls 2 and moves from 25 and lands at 27
# NEXT TURN =====================
#
# 5 =============================================================
# Player 1 rolls 3 and moves from 31 and lands at 34
# NEXT TURN =====================
#
# Player 2 rolls 3 and moves from 27 and lands at 30
# NEXT TURN =====================
#
# 6 =============================================================
# Player 1 rolls 5 and moves from 34 and lands at 39
# NEXT TURN =====================
#
# Player 2 rolls 5 and moves from 30 and lands at 35
# NEXT TURN =====================
#
# 7 =============================================================
# Player 1 rolls 2 and moves from 39 and lands at 41
# NEXT TURN =====================
#
# Player 2 rolls 6 and moves from 35 and lands at 41
# NEXT TURN =====================
#
# 8 =============================================================
# Player 1 rolls 1 and moves from 41 and lands at 42
# NEXT TURN =====================
#
# Player 2 rolls 4 and moves from 41 and lands at 45
# NEXT TURN =====================
#
# 9 =============================================================
# Player 1 rolls 6 and moves from 42 and lands at 48
# NEXT TURN =====================
#
# Player 2 rolls 4 and moves from 45 and lands at 49
# Player 2 is on a chute tile and moves down to 11
# NEXT TURN =====================
#
# 10 =============================================================
# Player 1 rolls 4 and moves from 48 and lands at 52
# NEXT TURN =====================
#
# Player 2 rolls 5 and moves from 11 and lands at 16
# NEXT TURN =====================
#
# 11 =============================================================
# Player 1 rolls 1 and moves from 52 and lands at 53
# NEXT TURN =====================
#
# Player 2 rolls 1 and moves from 16 and lands at 17
# Player 2 is on a chute tile and moves down to 4
# NEXT TURN =====================
#
# 12 =============================================================
# Player 1 rolls 2 and moves from 53 and lands at 55
# NEXT TURN =====================
#
# Player 2 rolls 6 and moves from 4 and lands at 10
# NEXT TURN =====================
#
# 13 =============================================================
# Player 1 rolls 3 and moves from 55 and lands at 58
# NEXT TURN =====================
#
# Player 2 rolls 6 and moves from 10 and lands at 16
# NEXT TURN =====================
#
# 14 =============================================================
# Player 1 rolls 6 and moves from 58 and lands at 64
# Player 1 is on a chute tile and moves down to 60
# NEXT TURN =====================
#
# Player 2 rolls 4 and moves from 16 and lands at 20
# NEXT TURN =====================
#
# 15 =============================================================
# Player 1 rolls 4 and moves from 60 and lands at 64
# Player 1 is on a chute tile and moves down to 60
# NEXT TURN =====================
#
# Player 2 rolls 4 and moves from 20 and lands at 24
# NEXT TURN =====================
#
# 16 =============================================================
# Player 1 rolls 4 and moves from 60 and lands at 64
# Player 1 is on a chute tile and moves down to 60
# NEXT TURN =====================
#
# Player 2 rolls 4 and moves from 24 and lands at 28
# Player 2 is on a ladder tile and moves up to 84
# NEXT TURN =====================
#
# 17 =============================================================
# Player 1 rolls 4 and moves from 60 and lands at 64
# Player 1 is on a chute tile and moves down to 60
# NEXT TURN =====================
#
# Player 2 rolls 5 and moves from 84 and lands at 89
# NEXT TURN =====================
#
# 18 =============================================================
# Player 1 rolls 1 and moves from 60 and lands at 61
# NEXT TURN =====================
#
# Player 2 rolls 6 and moves from 89 and lands at 95
# Player 2 is on a chute tile and moves down to 75
# NEXT TURN =====================
#
# 19 =============================================================
# Player 1 rolls 2 and moves from 61 and lands at 63
# NEXT TURN =====================
#
# Player 2 rolls 5 and moves from 75 and lands at 80
# Player 2 is on a ladder tile and moves up to 99
# NEXT TURN =====================
#
# 20 =============================================================
# Player 1 rolls 1 and moves from 63 and lands at 64
# Player 1 is on a chute tile and moves down to 60
# NEXT TURN =====================
#
# Player 2 overshoots square 100 and skips their turn
# NEXT TURN =====================
#
# 21 =============================================================
# Player 1 rolls 3 and moves from 60 and lands at 63
# NEXT TURN =====================
#
# Player 2 overshoots square 100 and skips their turn
# NEXT TURN =====================
#
# 22 =============================================================
# Player 1 rolls 5 and moves from 63 and lands at 68
# NEXT TURN =====================
#
# Player 2 overshoots square 100 and skips their turn
# NEXT TURN =====================
#
# 23 =============================================================
# Player 1 rolls 4 and moves from 68 and lands at 72
# NEXT TURN =====================
#
# Player 2 overshoots square 100 and skips their turn
# NEXT TURN =====================
#
# 24 =============================================================
# Player 1 rolls 2 and moves from 72 and lands at 74
# NEXT TURN =====================
#
# Player 2 overshoots square 100 and skips their turn
# NEXT TURN =====================
#
# 25 =============================================================
# Player 1 rolls 5 and moves from 74 and lands at 79
# NEXT TURN =====================
#
# Player 2 overshoots square 100 and skips their turn
# NEXT TURN =====================
#
# 26 =============================================================
# Player 1 rolls 5 and moves from 79 and lands at 84
# NEXT TURN =====================
#
# Player 2 overshoots square 100 and skips their turn
# NEXT TURN =====================
#
# 27 =============================================================
# Player 1 rolls 1 and moves from 84 and lands at 85
# NEXT TURN =====================
#
# Player 2 overshoots square 100 and skips their turn
# NEXT TURN =====================
#
# 28 =============================================================
# Player 1 rolls 4 and moves from 85 and lands at 89
# NEXT TURN =====================
#
# Player 2 overshoots square 100 and skips their turn
# NEXT TURN =====================
#
# 29 =============================================================
# Player 1 rolls 4 and moves from 89 and lands at 93
# Player 1 is on a chute tile and moves down to 73
# NEXT TURN =====================
#
# Player 2 rolls 1 and moves from 99 and lands at 100
# NEXT TURN =====================
#
#
# GAME END === WINNER is Player 2 at 29 turns
#
# 1 =============================================================
# Player 1 rolls 3 and moves from 0 and lands at 3
# NEXT TURN =====================
#
# Player 2 rolls 2 and moves from 0 and lands at 2
# Player 2 is on a ladder tile and moves up to 28
# NEXT TURN =====================
#
# 2 =============================================================
# Player 1 rolls 6 and moves from 3 and lands at 9
# Player 1 is on a ladder tile and moves up to 31
# NEXT TURN =====================
#
# Player 2 rolls 1 and moves from 28 and lands at 29
# NEXT TURN =====================
#
# 3 =============================================================
# Player 1 rolls 6 and moves from 31 and lands at 37
# NEXT TURN =====================
#
# Player 2 rolls 3 and moves from 29 and lands at 32
# NEXT TURN =====================
#
# 4 =============================================================
# Player 1 rolls 3 and moves from 37 and lands at 40
# NEXT TURN =====================
#
# Player 2 rolls 6 and moves from 32 and lands at 38
# NEXT TURN =====================
#
# 5 =============================================================
# Player 1 rolls 3 and moves from 40 and lands at 43
# NEXT TURN =====================
#
# Player 2 rolls 1 and moves from 38 and lands at 39
# NEXT TURN =====================
#
# 6 =============================================================
# Player 1 rolls 5 and moves from 43 and lands at 48
# NEXT TURN =====================
#
# Player 2 rolls 3 and moves from 39 and lands at 42
# NEXT TURN =====================
#
# 7 =============================================================
# Player 1 rolls 1 and moves from 48 and lands at 49
# Player 1 is on a chute tile and moves down to 11
# NEXT TURN =====================
#
# Player 2 rolls 6 and moves from 42 and lands at 48
# NEXT TURN =====================
#
# 8 =============================================================
# Player 1 rolls 3 and moves from 11 and lands at 14
# NEXT TURN =====================
#
# Player 2 rolls 5 and moves from 48 and lands at 53
# NEXT TURN =====================
#
# 9 =============================================================
# Player 1 rolls 4 and moves from 14 and lands at 18
# NEXT TURN =====================
#
# Player 2 rolls 2 and moves from 53 and lands at 55
# NEXT TURN =====================
#
# 10 =============================================================
# Player 1 rolls 5 and moves from 18 and lands at 23
# NEXT TURN =====================
#
# Player 2 rolls 5 and moves from 55 and lands at 60
# NEXT TURN =====================
#
# 11 =============================================================
# Player 1 rolls 6 and moves from 23 and lands at 29
# NEXT TURN =====================
#
# Player 2 rolls 2 and moves from 60 and lands at 62
# Player 2 is on a chute tile and moves down to 19
# NEXT TURN =====================
#
# 12 =============================================================
# Player 1 rolls 6 and moves from 29 and lands at 35
# NEXT TURN =====================
#
# Player 2 rolls 4 and moves from 19 and lands at 23
# NEXT TURN =====================
#
# 13 =============================================================
# Player 1 rolls 6 and moves from 35 and lands at 41
# NEXT TURN =====================
#
# Player 2 rolls 1 and moves from 23 and lands at 24
# NEXT TURN =====================
#
# 14 =============================================================
# Player 1 rolls 5 and moves from 41 and lands at 46
# NEXT TURN =====================
#
# Player 2 rolls 4 and moves from 24 and lands at 28
# Player 2 is on a ladder tile and moves up to 84
# NEXT TURN =====================
#
# 15 =============================================================
# Player 1 rolls 3 and moves from 46 and lands at 49
# Player 1 is on a chute tile and moves down to 11
# NEXT TURN =====================
#
# Player 2 rolls 2 and moves from 84 and lands at 86
# NEXT TURN =====================
#
# 16 =============================================================
# Player 1 rolls 3 and moves from 11 and lands at 14
# NEXT TURN =====================
#
# Player 2 rolls 3 and moves from 86 and lands at 89
# NEXT TURN =====================
#
# 17 =============================================================
# Player 1 rolls 3 and moves from 14 and lands at 17
# Player 1 is on a chute tile and moves down to 4
# NEXT TURN =====================
#
# Player 2 rolls 3 and moves from 89 and lands at 92
# NEXT TURN =====================
#
# 18 =============================================================
# Player 1 rolls 4 and moves from 4 and lands at 8
# NEXT TURN =====================
#
# Player 2 rolls 1 and moves from 92 and lands at 93
# Player 2 is on a chute tile and moves down to 73
# NEXT TURN =====================
#
# 19 =============================================================
# Player 1 rolls 4 and moves from 8 and lands at 12
# NEXT TURN =====================
#
# Player 2 rolls 2 and moves from 73 and lands at 75
# NEXT TURN =====================
#
# 20 =============================================================
# Player 1 rolls 5 and moves from 12 and lands at 17
# Player 1 is on a chute tile and moves down to 4
# NEXT TURN =====================
#
# Player 2 rolls 6 and moves from 75 and lands at 81
# NEXT TURN =====================
#
# 21 =============================================================
# Player 1 rolls 2 and moves from 4 and lands at 6
# NEXT TURN =====================
#
# Player 2 rolls 3 and moves from 81 and lands at 84
# NEXT TURN =====================
#
# 22 =============================================================
# Player 1 rolls 1 and moves from 6 and lands at 7
# Player 1 is on a ladder tile and moves up to 19
# NEXT TURN =====================
#
# Player 2 rolls 4 and moves from 84 and lands at 88
# NEXT TURN =====================
#
# 23 =============================================================
# Player 1 rolls 2 and moves from 19 and lands at 21
# Player 1 is on a ladder tile and moves up to 42
# NEXT TURN =====================
#
# Player 2 rolls 3 and moves from 88 and lands at 91
# NEXT TURN =====================
#
# 24 =============================================================
# Player 1 rolls 4 and moves from 42 and lands at 46
# NEXT TURN =====================
#
# Player 2 rolls 1 and moves from 91 and lands at 92
# NEXT TURN =====================
#
# 25 =============================================================
# Player 1 rolls 3 and moves from 46 and lands at 49
# Player 1 is on a chute tile and moves down to 11
# NEXT TURN =====================
#
# Player 2 rolls 3 and moves from 92 and lands at 95
# Player 2 is on a chute tile and moves down to 75
# NEXT TURN =====================
#
# 26 =============================================================
# Player 1 rolls 3 and moves from 11 and lands at 14
# NEXT TURN =====================
#
# Player 2 rolls 3 and moves from 75 and lands at 78
# NEXT TURN =====================
#
# 27 =============================================================
# Player 1 rolls 2 and moves from 14 and lands at 16
# NEXT TURN =====================
#
# Player 2 rolls 1 and moves from 78 and lands at 79
# NEXT TURN =====================
#
# 28 =============================================================
# Player 1 rolls 5 and moves from 16 and lands at 21
# Player 1 is on a ladder tile and moves up to 42
# NEXT TURN =====================
#
# Player 2 rolls 6 and moves from 79 and lands at 85
# NEXT TURN =====================
#
# 29 =============================================================
# Player 1 rolls 2 and moves from 42 and lands at 44
# NEXT TURN =====================
#
# Player 2 rolls 5 and moves from 85 and lands at 90
# NEXT TURN =====================
#
# 30 =============================================================
# Player 1 rolls 6 and moves from 44 and lands at 50
# NEXT TURN =====================
#
# Player 2 rolls 3 and moves from 90 and lands at 93
# Player 2 is on a chute tile and moves down to 73
# NEXT TURN =====================
#
# 31 =============================================================
# Player 1 rolls 1 and moves from 50 and lands at 51
# Player 1 is on a ladder tile and moves up to 67
# NEXT TURN =====================
#
# Player 2 rolls 2 and moves from 73 and lands at 75
# NEXT TURN =====================
#
# 32 =============================================================
# Player 1 rolls 1 and moves from 67 and lands at 68
# NEXT TURN =====================
#
# Player 2 rolls 4 and moves from 75 and lands at 79
# NEXT TURN =====================
#
# 33 =============================================================
# Player 1 rolls 6 and moves from 68 and lands at 74
# NEXT TURN =====================
#
# Player 2 rolls 2 and moves from 79 and lands at 81
# NEXT TURN =====================
#
# 34 =============================================================
# Player 1 rolls 3 and moves from 74 and lands at 77
# NEXT TURN =====================
#
# Player 2 rolls 6 and moves from 81 and lands at 87
# Player 2 is on a chute tile and moves down to 24
# NEXT TURN =====================
#
# 35 =============================================================
# Player 1 rolls 5 and moves from 77 and lands at 82
# NEXT TURN =====================
#
# Player 2 rolls 2 and moves from 24 and lands at 26
# NEXT TURN =====================
#
# 36 =============================================================
# Player 1 rolls 5 and moves from 82 and lands at 87
# Player 1 is on a chute tile and moves down to 24
# NEXT TURN =====================
#
# Player 2 rolls 5 and moves from 26 and lands at 31
# NEXT TURN =====================
#
# 37 =============================================================
# Player 1 rolls 6 and moves from 24 and lands at 30
# NEXT TURN =====================
#
# Player 2 rolls 1 and moves from 31 and lands at 32
# NEXT TURN =====================
#
# 38 =============================================================
# Player 1 rolls 6 and moves from 30 and lands at 36
# Player 1 is on a ladder tile and moves up to 44
# NEXT TURN =====================
#
# Player 2 rolls 5 and moves from 32 and lands at 37
# NEXT TURN =====================
#
# 39 =============================================================
# Player 1 rolls 1 and moves from 44 and lands at 45
# NEXT TURN =====================
#
# Player 2 rolls 2 and moves from 37 and lands at 39
# NEXT TURN =====================
#
# 40 =============================================================
# Player 1 rolls 6 and moves from 45 and lands at 51
# Player 1 is on a ladder tile and moves up to 67
# NEXT TURN =====================
#
# Player 2 rolls 3 and moves from 39 and lands at 42
# NEXT TURN =====================
#
# 41 =============================================================
# Player 1 rolls 1 and moves from 67 and lands at 68
# NEXT TURN =====================
#
# Player 2 rolls 2 and moves from 42 and lands at 44
# NEXT TURN =====================
#
# 42 =============================================================
# Player 1 rolls 2 and moves from 68 and lands at 70
# NEXT TURN =====================
#
# Player 2 rolls 5 and moves from 44 and lands at 49
# Player 2 is on a chute tile and moves down to 11
# NEXT TURN =====================
#
# 43 =============================================================
# Player 1 rolls 3 and moves from 70 and lands at 73
# NEXT TURN =====================
#
# Player 2 rolls 6 and moves from 11 and lands at 17
# Player 2 is on a chute tile and moves down to 4
# NEXT TURN =====================
#
# 44 =============================================================
# Player 1 rolls 6 and moves from 73 and lands at 79
# NEXT TURN =====================
#
# Player 2 rolls 2 and moves from 4 and lands at 6
# NEXT TURN =====================
#
# 45 =============================================================
# Player 1 rolls 3 and moves from 79 and lands at 82
# NEXT TURN =====================
#
# Player 2 rolls 3 and moves from 6 and lands at 9
# Player 2 is on a ladder tile and moves up to 31
# NEXT TURN =====================
#
# 46 =============================================================
# Player 1 rolls 1 and moves from 82 and lands at 83
# NEXT TURN =====================
#
# Player 2 rolls 5 and moves from 31 and lands at 36
# Player 2 is on a ladder tile and moves up to 44
# NEXT TURN =====================
#
# 47 =============================================================
# Player 1 rolls 3 and moves from 83 and lands at 86
# NEXT TURN =====================
#
# Player 2 rolls 3 and moves from 44 and lands at 47
# Player 2 is on a chute tile and moves down to 26
# NEXT TURN =====================
#
# 48 =============================================================
# Player 1 rolls 5 and moves from 86 and lands at 91
# NEXT TURN =====================
#
# Player 2 rolls 4 and moves from 26 and lands at 30
# NEXT TURN =====================
#
# 49 =============================================================
# Player 1 rolls 4 and moves from 91 and lands at 95
# Player 1 is on a chute tile and moves down to 75
# NEXT TURN =====================
#
# Player 2 rolls 4 and moves from 30 and lands at 34
# NEXT TURN =====================
#
# 50 =============================================================
# Player 1 rolls 3 and moves from 75 and lands at 78
# NEXT TURN =====================
#
# Player 2 rolls 6 and moves from 34 and lands at 40
# NEXT TURN =====================
#
# 51 =============================================================
# Player 1 rolls 3 and moves from 78 and lands at 81
# NEXT TURN =====================
#
# Player 2 rolls 3 and moves from 40 and lands at 43
# NEXT TURN =====================
#
# 52 =============================================================
# Player 1 rolls 5 and moves from 81 and lands at 86
# NEXT TURN =====================
#
# Player 2 rolls 6 and moves from 43 and lands at 49
# Player 2 is on a chute tile and moves down to 11
# NEXT TURN =====================
#
# 53 =============================================================
# Player 1 rolls 2 and moves from 86 and lands at 88
# NEXT TURN =====================
#
# Player 2 rolls 4 and moves from 11 and lands at 15
# NEXT TURN =====================
#
# 54 =============================================================
# Player 1 rolls 5 and moves from 88 and lands at 93
# Player 1 is on a chute tile and moves down to 73
# NEXT TURN =====================
#
# Player 2 rolls 3 and moves from 15 and lands at 18
# NEXT TURN =====================
#
# 55 =============================================================
# Player 1 rolls 1 and moves from 73 and lands at 74
# NEXT TURN =====================
#
# Player 2 rolls 5 and moves from 18 and lands at 23
# NEXT TURN =====================
#
# 56 =============================================================
# Player 1 rolls 2 and moves from 74 and lands at 76
# NEXT TURN =====================
#
# Player 2 rolls 6 and moves from 23 and lands at 29
# NEXT TURN =====================
#
# 57 =============================================================
# Player 1 rolls 5 and moves from 76 and lands at 81
# NEXT TURN =====================
#
# Player 2 rolls 3 and moves from 29 and lands at 32
# NEXT TURN =====================
#
# 58 =============================================================
# Player 1 rolls 5 and moves from 81 and lands at 86
# NEXT TURN =====================
#
# Player 2 rolls 2 and moves from 32 and lands at 34
# NEXT TURN =====================
#
# 59 =============================================================
# Player 1 rolls 6 and moves from 86 and lands at 92
# NEXT TURN =====================
#
# Player 2 rolls 5 and moves from 34 and lands at 39
# NEXT TURN =====================
#
# 60 =============================================================
# Player 1 rolls 1 and moves from 92 and lands at 93
# Player 1 is on a chute tile and moves down to 73
# NEXT TURN =====================
#
# Player 2 rolls 5 and moves from 39 and lands at 44
# NEXT TURN =====================
#
# 61 =============================================================
# Player 1 rolls 6 and moves from 73 and lands at 79
# NEXT TURN =====================
#
# Player 2 rolls 6 and moves from 44 and lands at 50
# NEXT TURN =====================
#
# 62 =============================================================
# Player 1 rolls 6 and moves from 79 and lands at 85
# NEXT TURN =====================
#
# Player 2 rolls 2 and moves from 50 and lands at 52
# NEXT TURN =====================
#
# 63 =============================================================
# Player 1 rolls 4 and moves from 85 and lands at 89
# NEXT TURN =====================
#
# Player 2 rolls 3 and moves from 52 and lands at 55
# NEXT TURN =====================
#
# 64 =============================================================
# Player 1 rolls 3 and moves from 89 and lands at 92
# NEXT TURN =====================
#
# Player 2 rolls 5 and moves from 55 and lands at 60
# NEXT TURN =====================
#
# 65 =============================================================
# Player 1 rolls 1 and moves from 92 and lands at 93
# Player 1 is on a chute tile and moves down to 73
# NEXT TURN =====================
#
# Player 2 rolls 6 and moves from 60 and lands at 66
# NEXT TURN =====================
#
# 66 =============================================================
# Player 1 rolls 6 and moves from 73 and lands at 79
# NEXT TURN =====================
#
# Player 2 rolls 3 and moves from 66 and lands at 69
# Player 2 is on a ladder tile and moves up to 81
# NEXT TURN =====================
#
# 67 =============================================================
# Player 1 rolls 5 and moves from 79 and lands at 84
# NEXT TURN =====================
#
# Player 2 rolls 3 and moves from 81 and lands at 84
# NEXT TURN =====================
#
# 68 =============================================================
# Player 1 rolls 3 and moves from 84 and lands at 87
# Player 1 is on a chute tile and moves down to 24
# NEXT TURN =====================
#
# Player 2 rolls 2 and moves from 84 and lands at 86
# NEXT TURN =====================
#
# 69 =============================================================
# Player 1 rolls 5 and moves from 24 and lands at 29
# NEXT TURN =====================
#
# Player 2 rolls 3 and moves from 86 and lands at 89
# NEXT TURN =====================
#
# 70 =============================================================
# Player 1 rolls 1 and moves from 29 and lands at 30
# NEXT TURN =====================
#
# Player 2 rolls 6 and moves from 89 and lands at 95
# Player 2 is on a chute tile and moves down to 75
# NEXT TURN =====================
#
# 71 =============================================================
# Player 1 rolls 1 and moves from 30 and lands at 31
# NEXT TURN =====================
#
# Player 2 rolls 3 and moves from 75 and lands at 78
# NEXT TURN =====================
#
# 72 =============================================================
# Player 1 rolls 3 and moves from 31 and lands at 34
# NEXT TURN =====================
#
# Player 2 rolls 4 and moves from 78 and lands at 82
# NEXT TURN =====================
#
# 73 =============================================================
# Player 1 rolls 6 and moves from 34 and lands at 40
# NEXT TURN =====================
#
# Player 2 rolls 1 and moves from 82 and lands at 83
# NEXT TURN =====================
#
# 74 =============================================================
# Player 1 rolls 2 and moves from 40 and lands at 42
# NEXT TURN =====================
#
# Player 2 rolls 2 and moves from 83 and lands at 85
# NEXT TURN =====================
#
# 75 =============================================================
# Player 1 rolls 6 and moves from 42 and lands at 48
# NEXT TURN =====================
#
# Player 2 rolls 4 and moves from 85 and lands at 89
# NEXT TURN =====================
#
# 76 =============================================================
# Player 1 rolls 5 and moves from 48 and lands at 53
# NEXT TURN =====================
#
# Player 2 rolls 1 and moves from 89 and lands at 90
# NEXT TURN =====================
#
# 77 =============================================================
# Player 1 rolls 5 and moves from 53 and lands at 58
# NEXT TURN =====================
#
# Player 2 rolls 1 and moves from 90 and lands at 91
# NEXT TURN =====================
#
# 78 =============================================================
# Player 1 rolls 3 and moves from 58 and lands at 61
# NEXT TURN =====================
#
# Player 2 rolls 3 and moves from 91 and lands at 94
# NEXT TURN =====================
#
# 79 =============================================================
# Player 1 rolls 3 and moves from 61 and lands at 64
# Player 1 is on a chute tile and moves down to 60
# NEXT TURN =====================
#
# Player 2 rolls 5 and moves from 94 and lands at 99
# NEXT TURN =====================
#
# 80 =============================================================
# Player 1 rolls 5 and moves from 60 and lands at 65
# NEXT TURN =====================
#
# Player 2 overshoots square 100 and skips their turn
# NEXT TURN =====================
#
# 81 =============================================================
# Player 1 rolls 2 and moves from 65 and lands at 67
# NEXT TURN =====================
#
# Player 2 overshoots square 100 and skips their turn
# NEXT TURN =====================
#
# 82 =============================================================
# Player 1 rolls 5 and moves from 67 and lands at 72
# NEXT TURN =====================
#
# Player 2 rolls 1 and moves from 99 and lands at 100
# NEXT TURN =====================
#
#
# GAME END === WINNER is Player 2 at 82 turns
